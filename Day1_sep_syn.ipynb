# %%
import numpy as np #numbers
import pandas as pd #load and manipulation
import matplotlib.pyplot as plt #data visualization
import seaborn as sns #data visualization

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/refs/heads/main/CardioGoodFitness-1.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.head(7)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 176   TM798   42   Male         18        Single      5        4   89641
#
#      Miles
# 176    200

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 93    TM498   23    Male         16     Partnered      3        3   45480
# 161   TM798   27    Male         21     Partnered      4        4   90886
# 76    TM195   44  Female         16        Single      3        4   57987
# 143   TM798   23    Male         16        Single      4        5   58516
# 175   TM798   40    Male         21        Single      6        5   83416
# 24    TM195   24    Male         14        Single      2        3   45480
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 115   TM498   31    Male         16     Partnered      3        3   52302
# 156   TM798   25    Male         20     Partnered      4        5   74701
# 89    TM498   23  Female         16        Single      3        3   45480
#
#      Miles
# 93      64
# 161    100
# 76      75
# 143    140
# 175    200
# 24     113
# 82     106
# 115     95
# 156    170
# 89      95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
sns.countplot(x="Product",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Gender",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
### Countplot-> Categorical(Object) or numerical with less unique values
### Univariate analysis

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
### univariate analysis-> Numerical columns -> Histogram

# %%
### Boxplot(Univariate Analysis-numerical)

# %%
sns.boxplot(x="Age",data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x="Education",data=df)
# Out:
# <Axes: xlabel='Education'>

# %%
#Education
#Income
#Miles
#Fitness
#Usage

# %%
### Bivariate analyis

# %%
### Product Vs Gender
sns.countplot(x="Product",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
### Diagnostic Analytics(Why did it happen?)
### Why TM 798 sales is less?

# %%
### Product Vs Marital status (All 3 prod are used by Partnered)

# %%
### Prod Vs Age (Boxplot)
sns.boxplot(x="Product",y="Age",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
### Product Vs Education
sns.boxplot(x="Product",y="Education",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Education'>

# %%
sns.boxplot(x="Product",y="Usage",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Usage'>

# %%
sns.boxplot(x="Product",y="Fitness",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Fitness'>

# %%
sns.boxplot(x="Product",y="Income",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
### Product and miles
sns.boxplot(x="Product",y="Miles",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Miles'>

# %%
### bivariate(Countplot,boxplot)

# %%
### Multivariate

# %%
sns.boxplot(x="Product",y="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
sns.violinplot(x="Product",y="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
sns.swarmplot(x="Product",y="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
### 3 new findings(Explore)
sns.swarmplot(x="Product",y="Education",hue="Gender",data=df)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 23.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Product', ylabel='Education'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 38.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 26.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
### Research (Nexus)

# %% [markdown]
# I have a dataset with columns like Product,Age,Gender,Education(Number of years),MaritalStatus,Usage,Fitness(1,2,3,4,5)Income,Miles.The Problem Statement is find whether there is any relationship b/w Product and Customer Characteristics.

# %% [markdown]
# Show code for interactive charts like plotly .
